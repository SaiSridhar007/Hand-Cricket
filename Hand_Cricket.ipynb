# %%
import random
Toss=input("ODD/EVEN?\n1.ODD\n2.EVEN\nEnter your choice: ")
user_runs=0
computer_runs=0
r = random.randint(0,10)
User = int(input("Enter your Call : "))
print (r)
sum = r + User
if Toss == "EVEN":
  if sum%2 == 0:
      print("You have won the toss")
      Toss = True
  else:
    print ("Computer won the toss")
    Toss = False
elif Toss == "ODD":
    if sum%2 != 0:
      print("You have won the toss")
      Toss = True
    else: 
      print("Computer won the toss")
      Toss= False
else:
  print("Wrong input")
if Toss == True:
  Playmode = input("Batting/Bowling?\n1.Batting\n2.Bownling\nEnter your choice: ")
  if Playmode == "Batting":
    print("You Chose to bat")
    while Toss == True:
      computer_input = random.randint(0 , 6)
      user_input = int(input("Enter Your input between 0 - 6"))
      print(computer_input)
      if computer_input == user_input:
        if user_runs == 0:
          print("You are duckout \n Your score is 0")
        else:
          print("You are Out \n You Scored", user_runs)
        break
      else:
        user_runs = user_runs + user_input
    print("Now its computer's turn to bat");
    while Toss == True:
      computer_input = random.randint(0 , 6)
      user_input = int(input("Enter your value from 0 - 6"))
      print(computer_input)
      if user_input == computer_input:
        print("Computer is out \n Computer scored", computer_runs)
        break
      else:
        computer_runs = computer_runs + computer_input;
    if computer_runs >= user_runs:
      print("Computer won the game");
    else:
      print("Hurray You won the game")
  else:
    print("You Chose to Bowl")
    while Toss == True:
      computer_input = random.randint(0 , 6)
      user_input = int(input("Enter your value from 0 - 6"))
      print(computer_input)
      if user_input == computer_input:
        print("Computer is out \n Computer scored", computer_runs)
        break
      else:
        computer_runs = computer_runs + computer_input;
    while Toss == True:
      computer_input = random.randint(0 , 6)
      user_input = int(input("Enter Your input between 0 - 6"))
      print(computer_input)
      if computer_input == user_input:
        if user_runs == 0:
          print("You are duckout \n Your score is 0");
        else:
          print("You are Out \n You Scored", user_runs)
        break;
      else:
        user_runs = user_runs + user_input
    if computer_runs >= user_runs:
      print("Computer won the game");
    else:
      print("Hurray You won the game");
else:
  Toss = ['Batting', 'Bowling']
  computer_desicion = random.choice(Toss)
  print ("Computer chose to : ", computer_desicion)
  if computer_desicion == "Bowling":
    while Toss == True:
      computer_input = random.randint(0 , 6)
      user_input = int(input("Enter your value from 0 - 6"))
      print(computer_input)
      if user_input == computer_input:
        print("Computer is out \n Computer scored", computer_runs)
        break
      else:
        computer_runs = computer_runs + computer_input;
    while Toss == True:
      computer_input = random.randint(0 , 6)
      user_input = int(input("Enter Your input between 0 - 6"))
      print(computer_input)
      if computer_input == user_input:
        if user_runs == 0:
          print("You are duckout \n Your score is 0");
        else:
          print("You are Out \n You Scored", user_runs)
        break;
      else:
        user_runs = user_runs + user_input
    if computer_runs >= user_runs:
      print("Computer won the game");
    else:
      print("Hurray You won the game");
  elif computer_desicion == "Batting":
    print("Computer Chose to bat")
    while Toss == True:
     computer_input = random.randint(0 , 6)
     user_input = int(input("Enter Your input between 0 - 6"))
     print(computer_input)
     if computer_input == user_input:
      if user_runs == 0:
          print("You are duckout \n Your score is 0")
          break;
      else:
        print("You are Out \n You Scored", user_runs)
        break;
    else:
        user_runs = user_runs + user_input
    print("Now its computer's turn to bat")
    while Toss == True:
      computer_input = random.randint(0 , 6)
      user_input = int(input("Enter your value from 0 - 6"))
      print(computer_input)
      if user_input == computer_input:
        print("Computer is out \n Computer scored", computer_runs)
        break
      else:
        computer_runs = computer_runs + computer_input;
    if computer_runs >= user_runs:
      print("Computer won the game");
    else:
      print("Hurray You won the game");
# Out:
# ODD/EVEN?
# 1.ODD
# 2.EVEN
# Enter your choice: ODD
# Enter your Call : 5
# 4
# You have won the toss
# Batting/Bowling?
# 1.Batting
# 2.Bownling
# Enter your choice: Bowling
# You Chose to Bowl
# Enter your value from 0 - 65
# 1
# Enter your value from 0 - 65
# Enter your value from 0 - 65
# 1
# 6
# Enter your value from 0 - 65
# 3
# Enter your value from 0 - 65
# Enter Your input between 0 - 65
# 5
# Computer is out
#  Computer scored 11
# 2
# Enter Your input between 0 - 65
# 1
# Enter Your input between 0 - 65
# 5
# You are Out
#  You Scored 10
# Computer won the game
